# %% [markdown]
# <a href="https://colab.research.google.com/github/HsiYuGit/FinForecast/blob/main/%5BFinForecast%5D_merge_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df1 = pd.read_csv("X_train.csv")
df2 = pd.read_csv("y_train.csv")

df = pd.concat([df1, df2], axis=1)

df.to_csv("train.csv", index=False)
